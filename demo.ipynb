# %%
import gbif_downloader as gbif

# %%
downloader = gbif.GBIFImages("Ixodes", 6, record_type="MATERIAL_SAMPLE", save_dir="Ixodes")
df = downloader.download_images()
# Out:
# https://api.gbif.org/v1/occurrence/search?media_type=StillImage&taxon_key=8326529&limit=6&basisOfRecord=MATERIAL_SAMPLE
# --- Found 6 records ---
# saving as Ixodes scapularis-57cdd161-db79-4133-a9cb-93cadecba5a5-Tick-ChaseM+1530471797.jpg
# saving as Ixodes pacificus-62983393-f628-4cf7-a790-ec4d810d3a69-DSC08113+1546045864.jpg
# saving as Ixodes gibbosus-74af5089-923f-4f87-be5b-91b87e5e6c20-ibx18d+1587125664.jpg
# saving as Ixodes gibbosus-2fd6b25e-ccf5-4aaf-b291-4f062a75f127-ibx15d+1586173882.jpg
# saving as Ixodes marxi-d161a54e-38c2-4094-badc-3995f118d39b-BIOUG30769-G12+1475257142.jpg
# saving as Ixodes marxi-4fbb04a1-af3b-4a3c-8ceb-04c5f27b9764-BIOUG30769-H08+1475257250.jpg
# Total size of images in this dataset: 0.001513269 GB

# %%
df
# Out:
#        format        type                                         references  \
# 0  image/jpeg  StillImage  http://bins.boldsystems.org/index.php/Public_R...
# 1  image/jpeg  StillImage  http://bins.boldsystems.org/index.php/Public_R...
# 2  image/jpeg  StillImage  http://bins.boldsystems.org/index.php/Public_R...
# 3  image/jpeg  StillImage  http://bins.boldsystems.org/index.php/Public_R...
# 4  image/jpeg  StillImage  http://bins.boldsystems.org/index.php/Public_R...
# 5  image/jpeg  StillImage  http://bins.boldsystems.org/index.php/Public_R...
#
#                                              license                title  \
# 0          CreativeCommons - Attribution Share-Alike  SDP758016-18 Dorsal
# 1  CreativeCommons - Attribution Non-Commercial S...    HVFW165-19 Dorsal
# 2  CreativeCommons - Attribution Non-Commercial S...     IBX010-20 Dorsal
# 3  CreativeCommons - Attribution Non-Commercial S...     IBX009-20 Dorsal
# ...
